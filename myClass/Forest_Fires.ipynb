# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv"

# %%
Forest_Fires = pd.read_csv(path)

# %%
Forest_Fires
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
Forest_Fires.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
Forest_Fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
sns.pairplot(Forest_Fires)

# %%
sns.displot(Forest_Fires)

# %%
sns.heatmap(Forest_Fires.corr())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11996\4015123664.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Forest_Fires.corr())
# <Axes: >

# %%
sns.heatmap(Forest_Fires.corr(), annot = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11996\2359681762.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Forest_Fires.corr(), annot = True)
# <Axes: >

# %%
sns.lmplot(x = 'temp', y= 'wind', data= Forest_Fires)

# %%
sns.jointplot(x="temp", y="wind", data=Graduate_Admissions, kind ='hex' )

# %%
sns.jointplot(x="FFMC", y="wind", data=Graduate_Admissions, kind ='hex' )

# %%
sns.lmplot(x = 'temp', y= 'FFMC', data= Forest_Fires)

# %%
Forest_Fires.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
X = Forest_Fires[['X', 'Y','DMC', 'DC', 'ISI', 'temp', 'RH',
       'wind', 'rain', 'area']]

# %%
y = Forest_Fires['FFMC']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_test
# Out:
#      X  Y    DMC     DC   ISI  temp  RH  wind  rain   area
# 310  7  4  105.8  758.1   9.9  25.3  27   2.7   0.0   0.00
# 89   6  5   35.8   80.8   7.8  17.4  25   4.9   0.0   0.00
# 483  8  6  130.3  587.1  14.1  31.0  27   5.4   0.0   0.00
# 443  1  2   80.9  368.3  16.8  14.8  78   8.0   0.0   0.00
# 81   1  2   99.6  631.2   6.3  17.9  44   2.2   0.0   0.00
# ..  .. ..    ...    ...   ...   ...  ..   ...   ...    ...
# 132  4  6   51.3  102.2   9.6  10.6  46   4.9   0.0   0.00
# 498  6  5  181.1  671.2  14.3  33.3  26   2.7   0.0  40.54
# 194  2  2  108.3  647.1  17.0  24.6  22   4.5   0.0  10.01
# 414  5  4  235.1  723.1  10.1  24.1  50   4.0   0.0   0.00
# 265  4  4  102.2  550.3  14.6  22.1  54   7.6   0.0   0.79
#
# [156 rows x 10 columns]

# %%
y_test
# Out:
# 310    92.4
# 89     91.7
# 483    94.9
# 443    90.7
# 81     90.2
#        ...
# 132    89.3
# 498    96.1
# 194    94.8
# 414    93.6
# 265    93.7
# Name: FFMC, Length: 156, dtype: float64

# %%
X_train
# Out:
#      X  Y    DMC     DC   ISI  temp  RH  wind  rain   area
# 175  1  4   96.9  624.2   8.9  20.3  39   4.9   0.0   4.53
# 442  6  5   24.9   41.6   3.7  10.9  64   3.1   0.0   3.35
# 291  9  4  104.2  474.9   9.0  25.3  39   0.9   0.0   8.00
# 202  7  4    8.7   32.1   2.1   8.8  68   2.2   0.0  13.05
# 222  4  3   52.2  103.8   5.0  11.0  46   5.8   0.0  36.85
# ..  .. ..    ...    ...   ...   ...  ..   ...   ...    ...
# 110  4  4   19.5   57.3   2.8  13.7  43   5.8   0.0   0.00
# 316  4  5   96.2  739.4   8.6  18.6  24   5.8   0.0   0.00
# 393  2  4   15.0   25.6  11.4  15.2  19   7.6   0.0   0.00
# 75   9  9    6.8   26.6   7.7   6.7  79   3.1   0.0   0.00
# 337  6  3  108.4  764.0   6.2  23.0  34   2.2   0.0  56.04
#
# [361 rows x 10 columns]

# %%
y_train
# Out:
# 175    90.2
# 442    87.9
# 291    91.6
# 202    83.9
# 222    87.6
#        ...
# 110    85.9
# 316    92.4
# 393    93.4
# 75     84.2
# 337    91.6
# Name: FFMC, Length: 361, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.34233975e-01, -1.22838488e-01,  2.46017819e-02,  1.42684133e-03,
#         4.65045836e-01, -4.27944681e-02, -1.19052382e-01,  6.06503330e-03,
#         7.64179863e-01,  4.11599038e-04])

# %%
pd.DataFrame(lm.coef_, X.columns, columns=['coeff'])
# Out:
#          coeff
# X     0.134234
# Y    -0.122838
# DMC   0.024602
# DC    0.001427
# ISI   0.465046
# temp -0.042794
# RH   -0.119052
# wind  0.006065
# rain  0.764180
# area  0.000412

# %%
from sklearn import metrics

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.displot((y_test-predictions),bins=50)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2.163744374610614
# MSE: 10.065244971307996
# RMSE: 3.172577023699818
